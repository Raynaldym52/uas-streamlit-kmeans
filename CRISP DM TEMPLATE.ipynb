# %% [markdown]
# # Business Understanding

# %% [markdown]
# ## Project Domain

# %%
# tentukan domain project yang akan dikerjakan misal bidang pertanian, lingkungan hidup, pendidikan, soaial, dll

# %%
# deskripsikan domain project ini dengan jelas dan lengkap
print("Data mengenai bencana adalah salah satu komponen yang sangat penting dalam rencana pengelolaan wilayah dan strategi pengurangan risiko bencana. Di Kabupaten Purwakarta, terdapat berbagai macam bencana, seperti banjir, tanah longsor, angin kencang, kebakaran hutan, kekeringan, dan pohon yang tumbang. Setiap kecamatan memiliki tingkat frekuensi bencana yang berbeda-beda, sehingga perlu dilakukan analisis yang berdasarkan data untuk memahami pola kerentanan bencana. Teknik Machine Learning, khususnya metode unsupervised learning dengan algoritma K-Means, dapat diterapkan untuk mengelompokkan kecamatan ke dalam beberapa kelompok berdasarkan risiko bencana yang dihadapi. Hasil dari pengelompokan ini akan mendukung pemerintah dalam menentukan prioritas untuk mitigasi, pengalokasian dana, serta kebijakan dalam penanganan bencana.")
# Out:
# Data mengenai bencana adalah salah satu komponen yang sangat penting dalam rencana pengelolaan wilayah dan strategi pengurangan risiko bencana. Di Kabupaten Purwakarta, terdapat berbagai macam bencana, seperti banjir, tanah longsor, angin kencang, kebakaran hutan, kekeringan, dan pohon yang tumbang. Setiap kecamatan memiliki tingkat frekuensi bencana yang berbeda-beda, sehingga perlu dilakukan analisis yang berdasarkan data untuk memahami pola kerentanan bencana. Teknik Machine Learning, khususnya metode unsupervised learning dengan algoritma K-Means, dapat diterapkan untuk mengelompokkan kecamatan ke dalam beberapa kelompok berdasarkan risiko bencana yang dihadapi. Hasil dari pengelompokan ini akan mendukung pemerintah dalam menentukan prioritas untuk mitigasi, pengalokasian dana, serta kebijakan dalam penanganan bencana.

# %% [markdown]
# ## Problem Statements

# %%
# tetukan poin-poin permasalahan yang ada dalam domain project
print("Data mengenai kejadian bencana di setiap kecamatan bersifat angka dan terdistribusi, sehingga pemerintah mengalami kesulitan dalam mengenali pola daerah yang rentan terhadap bencana. Hal ini menyebabkan tanpa adanya pengelompokan otomatis, sulit untuk menentukan prioritas lokasi yang memerlukan pendidikan tentang kebencanaan, peningkatan infrastruktur, dan persiapan logistik. Masalah ini semakin sulit karena anggaran untuk mitigasi sering dibagikan secara merata, meskipun ada variasi dalam tingkat kerawanan dan munculnya berbagai jenis bencana secara bersamaan (multi-hazard). Oleh karena itu, penting untuk menerapkan metode pengelompokan agar wilayah dapat diurutkan dan hubungan antar variabel dapat dianalisis, sehingga distribusi sumber daya bisa lebih tepat.")
# Out:
# Data mengenai kejadian bencana di setiap kecamatan bersifat angka dan terdistribusi, sehingga pemerintah mengalami kesulitan dalam mengenali pola daerah yang rentan terhadap bencana. Hal ini menyebabkan tanpa adanya pengelompokan otomatis, sulit untuk menentukan prioritas lokasi yang memerlukan pendidikan tentang kebencanaan, peningkatan infrastruktur, dan persiapan logistik. Masalah ini semakin sulit karena anggaran untuk mitigasi sering dibagikan secara merata, meskipun ada variasi dalam tingkat kerawanan dan munculnya berbagai jenis bencana secara bersamaan (multi-hazard). Oleh karena itu, penting untuk menerapkan metode pengelompokan agar wilayah dapat diurutkan dan hubungan antar variabel dapat dianalisis, sehingga distribusi sumber daya bisa lebih tepat.

# %% [markdown]
# ## Goals

# %%
# sebutkan tujuan membangun aplikasi ML ini sesuai permasalahan yang ada
print("1.Mengelompokkan kecamatan berdasarkan tingkat kejadian bencana.")
print("2.Mengidentifikasi kecamatan yang masuk kategori risiko rendah, sedang, atau tinggi.")
print("3.Menjadi dasar rekomendasi mitigasi bencana dan alokasi anggaran daerah.")
# Out:
# 1.Mengelompokkan kecamatan berdasarkan tingkat kejadian bencana.
# 2.Mengidentifikasi kecamatan yang masuk kategori risiko rendah, sedang, atau tinggi.
# 3.Menjadi dasar rekomendasi mitigasi bencana dan alokasi anggaran daerah.

# %% [markdown]
# ## Solution Statements

# %%
# sebutkan solusi aplikasi ai yang akan dibangun
print("Pengembangan model pembelajaran mesin yang menggunakan algoritma K-Means Clustering diusulkan untuk mengidentifikasi pola risiko alami dalam data terkait kejadian bencana yang tersebar. Algoritma K-Means dipilih karena cocok digunakan untuk data numerik, cepat, sederhana, dan mampu mengelompokkan kecamatan berdasarkan tingkat intensitas bencana ke dalam kluster Risiko Tinggi, Sedang, dan Rendah. Hasil pengelompokan ini selanjutnya dimanfaatkan untuk merancang rekomendasi mitigasi yang beragam, mulai dari anggaran besar dan pembangunan infrastruktur guna Risiko Tinggi, sampai pemantauan rutin bagi Risiko Sedang. Dengan cara ini, pendekatan ini memfasilitasi pemerintah daerah dalam menentukan daerah prioritas, mengoptimalkan pembagian anggaran, dan secara nyata meningkatkan efisiensi sistem mitigasi bencana.")
# Out:
# Pengembangan model pembelajaran mesin yang menggunakan algoritma K-Means Clustering diusulkan untuk mengidentifikasi pola risiko alami dalam data terkait kejadian bencana yang tersebar. Algoritma K-Means dipilih karena cocok digunakan untuk data numerik, cepat, sederhana, dan mampu mengelompokkan kecamatan berdasarkan tingkat intensitas bencana ke dalam kluster Risiko Tinggi, Sedang, dan Rendah. Hasil pengelompokan ini selanjutnya dimanfaatkan untuk merancang rekomendasi mitigasi yang beragam, mulai dari anggaran besar dan pembangunan infrastruktur guna Risiko Tinggi, sampai pemantauan rutin bagi Risiko Sedang. Dengan cara ini, pendekatan ini memfasilitasi pemerintah daerah dalam menentukan daerah prioritas, mengoptimalkan pembagian anggaran, dan secara nyata meningkatkan efisiensi sistem mitigasi bencana.

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Dataset Description

# %%
# Deskripsikan dataset yang digunakan

# %%
# berikan link sumber dataset (harus berasal dari public dataset)

# %%
# jelaskan cara membuat datasetnya

# %% [markdown]
# ## Libary Requirements

# %%
# Tentukan library yang dibutuhkan
import pandas as pd 

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, davies_bouldin_score
import matplotlib.pyplot as plt

import seaborn as sns
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("BencanaPWK2022.csv")

# %%
df.head()
# Out:
#    id Nama Kecamatan  pohon tumbang  angin_puting_beliung  longsor tanah  \
# 0   1      JATILUHUR              0                     2              3
# 1   2       SUKASARI              1                     1              2
# 2   3         MANIIS              0                     1              3
# 3   4     TEGAL WARU              0                     1              6
# 4   5         PLERED              0                     2              0
#
#    banjir  gempa  karhutla  bangunan ambruk  kekeringan  Jumlah Bencana  \
# 0       2      0         1                2           0              10
# 1       0      0         0                0           0               4
# 2       1      0         0                1           0               6
# 3       0      0         1                0           0               8
# 4       1      1         0                3           0               7
#
#    kecamatan_id kelas_kerawanan  kelas_id
# 0             6           Rawan         3
# 1            13          Sedang         2
# 2             8          Sedang         2
# 3            15          Sedang         2
# 4            10          Sedang         2

# %% [markdown]
# ## Exploratory Data Abalysis

# %%
# Buatkan EDA dan berikan deskripsinya :
# 2 line plot
# 2 box plot
# 2 pie chart
# scatter plot
# corelation matrix

# %%
#1. line plot untuk kejadian Longsor di berbagai Kecamatan
plt.figure(figsize=(8, 6))
sns.lineplot(data=df, x='longsor tanah', y='Nama Kecamatan', marker='o')
plt.title('Kejadian Longsor di kecamatan')
plt.ylabel('Nama Kecmatan')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#2. line plot untuk kejadian karhutla di berbagai Kecamatan
plt.figure(figsize=(8, 6))
sns.lineplot(data=df, x='karhutla', y='Nama Kecamatan', marker='o')
plt.title('Kejadian Karhutla di kecamatan')
plt.ylabel('Nama Kecmatan')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#1. Box Plot Kejadian Pohon tumbang berdasarkan kelas kerawanan
sns.boxplot(data=df,
            x='pohon tumbang',
            y='kelas_id',
            palette='Set3')
plt.title("Kejadian Pohon tumbang berdasarkan kelas kerawanan")
plt.xlabel("Pohon Tumbang")
plt.ylabel("Kelas Id")
plt.xticks(rotation=30)
plt.show()
# Out:
# C:\Users\usern\AppData\Local\Temp\ipykernel_7780\2007700786.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,

# %%
#2. box plot Kejadian Angin Puting Beliung berdasarkan kelas kerawanan
sns.boxplot(data=df,
            x='angin_puting_beliung',
            y='kelas_id',
            palette='Set3')
plt.title("Kejadian Angin Puting Beliung berdasarkan kelas kerawanan")
plt.xlabel("Angin Puting Beliung")
plt.ylabel("Kelas Id")
plt.xticks(rotation=30)
plt.show()
# Out:
# C:\Users\usern\AppData\Local\Temp\ipykernel_7780\786360883.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,

# %%
# 1.Pie Chart
banjir_counts = df['banjir'].value_counts()
plt.pie(banjir_counts,
        labels=banjir_counts.index,
        autopct='%1.1f%%',
        colors=['skyblue', 'red', 'yellow', 'pink', 'green'],
        startangle=80)
plt.title("BAnjir Counts")
plt.show()

# %%
BA_counts = df['bangunan ambruk'].value_counts()
plt.pie(BA_counts,
        labels=BA_counts.index,
        autopct='%1.1f%%',
        colors=['blue', 'skyblue', 'red', 'yellow', 'pink', 'orange', 'green'],
        startangle=80)
plt.title("Bangunan Ambruk Counts")
plt.show()

# %%
#scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='bangunan ambruk', y='kelas_id', data=df)
plt.title('Scatter Plot untuk Bangunan Ambruk')
plt.xlabel('Bangunan Ambruk')
plt.ylabel('Kelas id')
plt.show()

# %%
quant_cols = ['pohon tumbang', 'angin_puting_beliung', 'longsor tanah', 'banjir', 'gempa', 'karhutla', 'bangunan ambruk', 'kekeringan', 'kelas_id']
df_features = df[quant_cols]

correlation_matrix = df_features.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    linewidths=.5,
    cbar=True
)
plt.title('Correlation Matrix Pada Kejadian Bencana')
plt.show()

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Dataset Information

# %%
# berikan informasi dataset seperti jumlah kolom, jumlah baris, tipe data, dll
print("Bentuk Dataset:", df.shape)
print("\nInformasi Tipe Data:")
print(df.info())
print("\nLima baris pertama:")
print(df.head())
# Out:
# Bentuk Dataset: (17, 14)
#
# Informasi Tipe Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    17 non-null     int64
#  1   Nama Kecamatan        17 non-null     object
#  2   pohon tumbang         17 non-null     int64
#  3   angin_puting_beliung  17 non-null     int64
#  4   longsor tanah         17 non-null     int64
#  5   banjir                17 non-null     int64
#  6   gempa                 17 non-null     int64
#  7   karhutla              17 non-null     int64
#  8   bangunan ambruk       17 non-null     int64
#  9   kekeringan            17 non-null     int64
#  10  Jumlah Bencana        17 non-null     int64
#  11  kecamatan_id          17 non-null     int64
#  12  kelas_kerawanan       17 non-null     object
#  13  kelas_id              17 non-null     int64
# dtypes: int64(12), object(2)
# memory usage: 2.0+ KB
# None
#
# Lima baris pertama:
#    id Nama Kecamatan  pohon tumbang  angin_puting_beliung  longsor tanah  \
# 0   1      JATILUHUR              0                     2              3
# 1   2       SUKASARI              1                     1              2
# 2   3         MANIIS              0                     1              3
# 3   4     TEGAL WARU              0                     1              6
# 4   5         PLERED              0                     2              0
#
#    banjir  gempa  karhutla  bangunan ambruk  kekeringan  Jumlah Bencana  \
# 0       2      0         1                2           0              10
# 1       0      0         0                0           0               4
# 2       1      0         0                1           0               6
# 3       0      0         1                0           0               8
# 4       1      1         0                3           0               7
#
#    kecamatan_id kelas_kerawanan  kelas_id
# 0             6           Rawan         3
# 1            13          Sedang         2
# 2             8          Sedang         2
# 3            15          Sedang         2
# 4            10          Sedang         2

# %% [markdown]
# ## Dataset Transformation

# %%
# jelaskan bagaimana dataset ditransformasikan sebelum diolah menggunakan model ML

# %%
# bisa menggunakan auto encoder atau manual menggunakan bins
df = df.fillna(0)

# %%
features_cols =['Jumlah Bencana', 'kelas_id']
X = df[features_cols]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## Determine Variabels

# %%
# tentukan variabel apa saja yang digunakan sebagai fitur/label
features_cols
# Out:
# ['Jumlah Bencana', 'kelas_id']

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Modeling classification / clustering

# %%
# buatkan modeling menggunakan algoritma ML
# Menentukan nilai k optimal menggunakan Metode Elbow
inertia = []
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Visualisasi Elbow Method
plt.figure(figsize=(8, 5))
plt.plot(K_range, inertia, marker='o')
plt.title('Elbow Method untuk K-Means')
plt.xlabel('Jumlah Cluster (K)')
plt.ylabel('Inertia')
plt.grid(True)
plt.show()

# Berdasarkan plot elbow (asumsi titik siku optimal adalah K=3)
optimal_k = 3
print(f"Berdasarkan Metode Elbow, diasumsikan K optimal adalah: {optimal_k}")
# Out:
# Berdasarkan Metode Elbow, diasumsikan K optimal adalah: 3

# %%
# ada 2 plihihan bisa menggunakan supervised learning / unsupervised learning
# Menerapkan K-Means dengan k optimal
kmeans_model = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
df['Cluster'] = kmeans_model.fit_predict(X_scaled)

print(f"\nModel K-Means telah dilatih dengan K = {optimal_k}")
print("Hasil Clustering ditambahkan ke dataframe pada kolom 'Cluster'.")

# Melihat distribusi data per cluster
print("\nDistribusi Data per Cluster:")
print(df['Cluster'].value_counts())
# Out:
# Model K-Means telah dilatih dengan K = 3
# Hasil Clustering ditambahkan ke dataframe pada kolom 'Cluster'.
#
# Distribusi Data per Cluster:
# Cluster
# 1    7
# 2    6
# 0    4
# Name: count, dtype: int64

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Model evaluation classification / clustering

# %%
# tentukan metode evaluasi yang digunakan dan berikan penjelasan terhadap hasil evaluasinya
# Tentukan metode evaluasi yang digunakan dan berikan penjelasan terhadap hasil evaluasinya

# 1. Silhouette Score (nilai mendekati 1.0 adalah yang terbaik)
score_sil = silhouette_score(X_scaled, df['Cluster'])
print(f"\nSilhouette Score: {score_sil:.4f}")
print("Penjelasan: Silhouette Score mengukur seberapa mirip suatu objek dengan clusternya sendiri (cohesion) dibandingkan dengan cluster lain (separation). Nilai yang lebih tinggi (mendekati 1) menunjukkan bahwa objek dikelompokkan dengan baik.")

# 2. Davies-Bouldin Index (nilai mendekati 0.0 adalah yang terbaik)
score_db = davies_bouldin_score(X_scaled, df['Cluster'])
print(f"Davies-Bouldin Index: {score_db:.4f}")
print("Penjelasan: Davies-Bouldin Index mengukur rasio dispersi intra-cluster (seberapa padat cluster) terhadap separasi antar-cluster. Nilai yang lebih rendah (mendekati 0) menunjukkan clustering yang lebih baik.")

# Analisis Profil Cluster
print("\nProfil Rata-rata Fitur per Cluster (dalam skala asli):")
df_profil = df.groupby('Cluster')[features_cols].mean().reset_index()
print(df_profil)
# Profiling ini membantu dalam interpretasi:
# Cluster 0: Mungkin merupakan wilayah dengan dampak bencana rendah.
# Cluster 1: Mungkin merupakan wilayah dengan dampak bencana sedang.
# Cluster 2: Mungkin merupakan wilayah dengan dampak bencana tinggi.
# Out:
# Silhouette Score: 0.6624
# Penjelasan: Silhouette Score mengukur seberapa mirip suatu objek dengan clusternya sendiri (cohesion) dibandingkan dengan cluster lain (separation). Nilai yang lebih tinggi (mendekati 1) menunjukkan bahwa objek dikelompokkan dengan baik.
# Davies-Bouldin Index: 0.4280
# Penjelasan: Davies-Bouldin Index mengukur rasio dispersi intra-cluster (seberapa padat cluster) terhadap separasi antar-cluster. Nilai yang lebih rendah (mendekati 0) menunjukkan clustering yang lebih baik.
#
# Profil Rata-rata Fitur per Cluster (dalam skala asli):
#    Cluster  Jumlah Bencana  kelas_id
# 0        0       26.000000  4.000000
# 1        1        5.142857  1.857143
# 2        2       13.166667  3.000000

# %%
# untuk supervised bisa menggunakan mse, rmse, atau confusion matrix

# %%
# untuk unsupervised bisa gunakan sillouete atau davies bouldin

# %% [markdown]
# # Deployment

# %% [markdown]
# ## Model Simulation

# %%
# simulasika model dengan inputan data baru
# Contoh data baru 
new_data = pd.DataFrame({
    'Jumlah Bencana': [6], 
    'kelas_id': [2]
})
# Scaling data baru menggunakan scaler yang sudah dilatih
new_data_scaled = scaler.transform(new_data)

# Memprediksi cluster
new_clusters = kmeans_model.predict(new_data_scaled)

new_data['Predicted_Cluster'] = new_clusters

print("\nHasil Simulasi Data Baru:")
print(new_data)
# Out:
# Hasil Simulasi Data Baru:
#    Jumlah Bencana  kelas_id  Predicted_Cluster
# 0               6         2                  1

# %% [markdown]
# ## Save Model

# %%
# simpan model sebelum dilanjutkan ke aplikasi streamlit
# simpan model sebelum dilanjutkan ke aplikasi streamlit
import joblib

# Simpan model K-Means
joblib.dump(kmeans_model, 'kmeans_model.pkl')
print("Model K-Means (kmeans_model.pkl) berhasil disimpan.")

# Simpan Scaler (PENTING! harus disimpan untuk standardisasi input deployment)
joblib.dump(scaler, 'scaler.pkl')
print("Model Scaler (scaler.pkl) berhasil disimpan.")
